# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('flights.csv')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_airlines = pd.read_csv('airlines.csv')
data_airports = pd.read_csv('airports.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE                object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# ...

# %%
data.head(10)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
# 5  2015      1    1            4      DL            806      N3730B
# 6  2015      1    1            4      NK            612      N635NK
# 7  2015      1    1            4      US           2013      N584UW
# 8  2015      1    1            4      AA           1112      N3LAAA
# 9  2015      1    1            4      DL           1173      N826DN
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# ...

# %%
data.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# ...

# %%
data.AIR_SYSTEM_DELAY.isnull().sum()/data.shape[0]
# Out:
# 0.81724960255738066

# %%
data.AIR_SYSTEM_DELAY.nunique()
# Out:
# 570

# %%
fig,ax = plt.subplots(nrows =1, ncols = 1, figsize = (30,25))

corr = data.corr()
sns.heatmap(corr, annot = True)

# %%
data.DESTINATION_AIRPORT.value_counts()
# Out:
# ATL      346904
# ORD      285906
# DFW      239582
# DEN      196010
# LAX      194696
# SFO      147966
# PHX      146812
# IAH      146683
# LAS      133198
# MSP      112128
# MCO      110980
# SEA      110907
# DTW      108398
# BOS      107851
# EWR      101830
# CLT      100322
# LGA       99581
# SLC       97193
# JFK       93809
# BWI       86085
# MDW       80884
# DCA       73799
# FLL       73599
# SAN       70207
# MIA       69324
# PHL       66017
# TPA       63914
# DAL       59703
# HOU       52041
# BNA       47568
#           ...
# 12888         3
# 11525         3
# 12335         3
# 10577         3
# 12255         3
# 11617         3
# 11587         3
# 13127         3
# 11898         3
# 11980         3
# 11013         3
# 14113         3
# 10918         3
# 10739         3
# 10333         3
# 12177         3
# 13502         2
# 11447         2
# 10268         2
# 10581         2
# 11097         2
# 12016         2
# 10170         2
# 13964         1
# ...

# %%
data['DATE'] = pd.to_datetime(data[['YEAR','MONTH', 'DAY']])

# %%
data.DATE.nunique()
# Out:
# 365

# %%
print (data.CANCELLED.sum())
print (data.shape[0] - data.CANCELLATION_REASON.isnull().sum())
# Out:
# 89884
# 89884

# %%
merged_data = pd.merge(data, data_airlines, left_on='AIRLINE', right_on='IATA_CODE', how='inner')
merged_data.drop('IATA_CODE', axis=1, inplace=True)

# %%
merged_data.rename(columns={'AIRLINE_x': 'AIRLINE_CODE','AIRLINE_y': 'AIRLINE'}, inplace=True)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5819079 entries, 0 to 5819078
# Data columns (total 33 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE_CODE           object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# ...

# %%
df = pd.merge(merged_data, data_airports, left_on='ORIGIN_AIRPORT', right_on='IATA_CODE', how='inner')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332914 entries, 0 to 5332913
# Data columns (total 40 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE_CODE           object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# ...

# %%
df.drop(['IATA_CODE','LATITUDE','LONGITUDE'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE_CODE                 0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14367
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           83814
# DEPARTURE_DELAY          83814
# TAXI_OUT                 86612
# WHEELS_OFF               86612
# SCHEDULED_TIME               6
# ELAPSED_TIME            101784
# AIR_TIME                101784
# DISTANCE                     0
# WHEELS_ON                89942
# TAXI_IN                  89942
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             89942
# ARRIVAL_DELAY           101784
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5245484
# AIR_SYSTEM_DELAY       4329554
# SECURITY_DELAY         4329554
# AIRLINE_DELAY          4329554
# LATE_AIRCRAFT_DELAY    4329554
# ...

# %%
print("Average AIR_SYSTEM_DELAY of a flight is:", df.AIR_SYSTEM_DELAY.sum()/df[df.AIR_SYSTEM_DELAY.notnull()==True].AIR_SYSTEM_DELAY.count())
print("Average SECURITY_DELAY of a flight is:", df.SECURITY_DELAY.sum()/df[df.SECURITY_DELAY.notnull()==True].SECURITY_DELAY.count())
print("Average AIRLINE_DELAY of a flight is:", df.AIRLINE_DELAY.sum()/df[df.AIRLINE_DELAY.notnull()==True].AIRLINE_DELAY.count())
print("Average LATE_AIRCRAFT_DELAY of a flight is:", df.LATE_AIRCRAFT_DELAY.sum()/df[df.LATE_AIRCRAFT_DELAY.notnull()==True].LATE_AIRCRAFT_DELAY.count())
print("Average WEATHER_DELAY of a flight is:", df.WEATHER_DELAY.sum()/df[df.WEATHER_DELAY.notnull()==True].WEATHER_DELAY.count())
# Out:
# Average AIR_SYSTEM_DELAY of a flight is: 13.4877461729
# Average SECURITY_DELAY of a flight is: 0.0776839818211
# Average AIRLINE_DELAY of a flight is: 18.903429477
# Average LATE_AIRCRAFT_DELAY of a flight is: 23.6880820443
# Average WEATHER_DELAY of a flight is: 2.98099186733

# %%
print("Avg ARRIVAL_DELAY of a flight is:",df[df.ARRIVAL_DELAY >0].ARRIVAL_DELAY.sum()/df[df.ARRIVAL_DELAY.notnull()==True].ARRIVAL_DELAY.count())
print("Avg DEPARTURE_DELAY of a flight is:",df[df.DEPARTURE_DELAY >0].DEPARTURE_DELAY.sum()/df[df.DEPARTURE_DELAY.notnull()==True].DEPARTURE_DELAY.count())
# Out:
# Avg ARRIVAL_DELAY of a flight is: 12.48206334
# Avg DEPARTURE_DELAY of a flight is: 12.4922331447

# %%
# plt.figure(figsize=(20, 8))

# ax1 = df.plot(kind='scatter', x='SCHEDULED_DEPARTURE', y='AIR_SYSTEM_DELAY',figsize=(20,8), color='r')
# ax2 = df.plot(kind='scatter', x='SCHEDULED_DEPARTURE', y='SECURITY_DELAY', color='b', ax=ax1)
# ax3 = df.plot(kind='scatter', x='SCHEDULED_DEPARTURE', y='AIRLINE_DELAY', color='y', ax=ax1)
# ax4 = df.plot(kind='scatter', x='SCHEDULED_DEPARTURE', y='LATE_AIRCRAFT_DELAY', color='g', ax=ax1)
# ax5 = df.plot(kind='scatter', x='SCHEDULED_DEPARTURE', y='WEATHER_DELAY', color='m', ax=ax1)


# ax1.set_xlabel("Time (HHMM)")
# ax1.set_ylabel("Time Delayed")
# plt.title('All Delays')

# %%
df[df.CANCELLATION_REASON.notnull() ==True].CANCELLATION_REASON.value_counts()
# Out:
# B    47874
# A    24309
# C    15225
# D       22
# Name: CANCELLATION_REASON, dtype: int64

# %%
df['CANCELLATION_REASON']=df.CANCELLATION_REASON.replace({'A':'Airline/Carrier','B':'Weather','C':'National Air System','D':'Security',np.nan:0})

# %%
df.CANCELLATION_REASON.value_counts()
# Out:
# 0                      5245484
# Weather                  47874
# Airline/Carrier          24309
# National Air System      15225
# Security                    22
# Name: CANCELLATION_REASON, dtype: int64

# %%
pd.DataFrame({'cancellation_rate' : df[df.CANCELLED==0].groupby(['AIRLINE'])['CANCELLED'].count()}).plot(kind='bar')

# %% [markdown]
# ** Southwest has the maximum number of cancellation rate**

# %% [markdown]
# **Flight Data Relationship**
#
# 1. departure_time = wheels_off - taxi_out
#
# 2. departure_delay = departure_time - scheduled_departure
#
# 3. arrival_time = wheels_on + taxi_in
#
# 4. arrival_delay = arrival_time - scheduled_arrival
#
# 5. elapsed_time =air_time + taxi_in + taxi_out
#
# 6. air_time = wheels_on - wheels_off

# %%
df_temp=df

# %%
selected_columns = ['AIRLINE_CODE','ORIGIN_AIRPORT','CANCELLATION_REASON','AIRPORT','CITY','STATE','COUNTRY']
df_temp_dummy = pd.get_dummies(df_temp[selected_columns])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332914 entries, 0 to 5332913
# Data columns (total 37 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE_CODE           object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# ...

# %%
df_temp_dummy.shape
# Out:
# (5332914, 1026)

# %%
pd.DataFrame({'# of flights delayed for each airline' :df[df.ARRIVAL_DELAY >0].groupby('AIRLINE')['ARRIVAL_DELAY'].count()}).plot(kind='bar')

# %%
def value_range(x):
    if x >=12:
        return 1
    else:
        return 0

# %%
df['ARRIVAL_DELAY_12'] = df['ARRIVAL_DELAY'].apply(value_range)

# %%
df['ARRIVAL_DELAY_12'].value_counts()
# Out:
# 0    4198928
# 1    1133986
# Name: ARRIVAL_DELAY_12, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332914 entries, 0 to 5332913
# Data columns (total 38 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE_CODE           object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# ...

# %%
df_temp = df

# %%
df['DAY_OF_WEEK'] = df['DAY_OF_WEEK'].replace({1:'MONDAY',2:'TUESDAY',3:'WEDNESDAY',4:'THURSDAY',5:'FRIDAY',6:'SATURDAY',7:'SUNDAY'})

# %%
df['MONTH'] = df['MONTH'].replace({1:'JAN',2:'FEB',3:'MAR',4:'APRIL',5:'MAY',6:'JUN',7:'JUL',8:'AUG',9:'SEP',10:'OCT',11:'NOV',12:'DEC'})

# %%
grouped_df = df.groupby(['DAY_OF_WEEK','AIRLINE'])['DEPARTURE_DELAY'].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('DAY_OF_WEEK','AIRLINE','DEPARTURE_DELAY')

plt.figure(figsize=(12,6))
sns.heatmap(grouped_df,linecolor="w", linewidths=1)
plt.title("Frequency of Day of week Vs AIRLINE")
plt.show()

# %%
df = df.drop(['ELAPSED_TIME','AIR_TIME','TAIL_NUMBER','DISTANCE','WHEELS_OFF','TAIL_NUMBER','DEPARTURE_TIME','WHEELS_ON','YEAR'],axis=1)

# %%
fig,ax = plt.subplots(nrows =1, ncols = 1, figsize = (30,25))
corr = df.corr()
sns.heatmap(corr, annot = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332914 entries, 0 to 5332913
# Data columns (total 30 columns):
# MONTH                  object
# DAY                    int64
# DAY_OF_WEEK            object
# AIRLINE_CODE           object
# FLIGHT_NUMBER          int64
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# SCHEDULED_TIME         float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# DATE                   datetime64[ns]
# AIRLINE                object
# AIRPORT                object
# CITY                   object
# ...

# %%
df.isnull().sum()
# Out:
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE_CODE                 0
# FLIGHT_NUMBER                0
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_DELAY          83814
# TAXI_OUT                 86612
# SCHEDULED_TIME               6
# TAXI_IN                  89942
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             89942
# ARRIVAL_DELAY           101784
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON          0
# AIR_SYSTEM_DELAY       4329554
# SECURITY_DELAY         4329554
# AIRLINE_DELAY          4329554
# LATE_AIRCRAFT_DELAY    4329554
# WEATHER_DELAY          4329554
# DATE                         0
# AIRLINE                      0
# AIRPORT                      0
# CITY                         0
# STATE                        0
# COUNTRY                      0
# ARRIVAL_DELAY_12             0
# ...

# %%
df.dropna(axis=0, subset=['ARRIVAL_DELAY'],how='any',inplace=True)

# %%
df.isnull().sum()
# Out:
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE_CODE                 0
# FLIGHT_NUMBER                0
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_DELAY              0
# TAXI_OUT                     0
# SCHEDULED_TIME               0
# TAXI_IN                      0
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME                 0
# ARRIVAL_DELAY                0
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON          0
# AIR_SYSTEM_DELAY       4227770
# SECURITY_DELAY         4227770
# AIRLINE_DELAY          4227770
# LATE_AIRCRAFT_DELAY    4227770
# WEATHER_DELAY          4227770
# DATE                         0
# AIRLINE                      0
# AIRPORT                      0
# CITY                         0
# STATE                        0
# COUNTRY                      0
# ARRIVAL_DELAY_12             0
# ...

# %%
df_temp=df

# %%
cols = ['AIR_SYSTEM_DELAY','SECURITY_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY']
df[cols] = df[cols].replace({np.nan:0,np.nan:0,np.nan:0,np.nan:0})

# %%
df.isnull().sum()
# Out:
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# AIRLINE_CODE           0
# FLIGHT_NUMBER          0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_DELAY        0
# TAXI_OUT               0
# SCHEDULED_TIME         0
# TAXI_IN                0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# CANCELLATION_REASON    0
# AIR_SYSTEM_DELAY       0
# SECURITY_DELAY         0
# AIRLINE_DELAY          0
# LATE_AIRCRAFT_DELAY    0
# WEATHER_DELAY          0
# DATE                   0
# AIRLINE                0
# AIRPORT                0
# CITY                   0
# STATE                  0
# COUNTRY                0
# ARRIVAL_DELAY_12       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5231130 entries, 0 to 5332913
# Data columns (total 30 columns):
# MONTH                  object
# DAY                    int64
# DAY_OF_WEEK            object
# AIRLINE_CODE           object
# FLIGHT_NUMBER          int64
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# SCHEDULED_TIME         float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# DATE                   datetime64[ns]
# AIRLINE                object
# AIRPORT                object
# CITY                   object
# ...

# %%
df.to_csv('data_temp1.csv',encoding='utf-8-sig')

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.3)

# %%
train.shape
# Out:
# (3661791, 30)

# %%
train.to_csv('data_train.csv',encoding='utf-8-sig')

# %%
test.shape
# Out:
# (1569339, 30)

# %%
test.to_csv('data_test.csv',encoding='utf-8-sig')

# %%
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve, auc

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV

clf1 = SGDClassifier(loss='log', penalty='l1', learning_rate='constant',class_weight={0:0.64,1:2.3}, n_jobs=-1, random_state=10, eta0=0.01)

# %%
from sklearn.feature_extraction import FeatureHasher

fh = FeatureHasher(n_features = 2**15, input_type="string")

y_test = test["ARRIVAL_DELAY_12"]
X_test = fh.transform(np.asarray(test.iloc[:,0:-1].astype(str)))

# %%
chunksize = 200000
trainloss1 = []
testloss1 = []

for i,chunk in enumerate(pd.read_csv('data_train.csv', chunksize=chunksize)):
    X_train = fh.transform(np.asarray(chunk.iloc[:,0:-1].astype(str)))
    y_train = chunk.iloc[:,-1]    
    clf1.partial_fit(X_train,y_train,classes=[0,1])
    fpr, tpr, thresholds = metrics.roc_curve(y_train,clf1.predict(X_train))
    trainloss1.append(metrics.auc(fpr, tpr))
    fpr_t, tpr_t, thresholds_t = metrics.roc_curve(y_test,clf1.predict(X_test))
    testloss1.append(metrics.auc(fpr_t, tpr_t))

# %%
print("train_errorloss:",np.mean(trainloss))
print("train_errorloss:",np.mean(testloss))

plt.plot(trainloss1)
plt.plot(testloss1)
plt.legend(('train','test'))
plt.show()
# Out:
# train_errorloss: 0.956672231293
# train_errorloss: 0.956797160841

# %%
clf2 = SGDClassifier(loss='hinge', penalty='l1', learning_rate='constant',class_weight={0:0.64,1:2.3}, n_jobs=-1, random_state=10, eta0=0.01)

# %%
trainloss2 = []
testloss2 = []

for i,chunk in enumerate(pd.read_csv('data_train.csv', chunksize=chunksize)):
    X_train = fh.transform(np.asarray(chunk.iloc[:,0:-1].astype(str)))
    y_train = chunk.iloc[:,-1]    
    clf2.partial_fit(X_train,y_train,classes=[0,1])
    fpr, tpr, thresholds = metrics.roc_curve(y_train,clf2.predict(X_train))
    trainloss2.append(metrics.auc(fpr, tpr))
    fpr_t, tpr_t, thresholds_t = metrics.roc_curve(y_test,clf2.predict(X_test))
    testloss2.append(metrics.auc(fpr_t, tpr_t))

# %%
print("train_errorloss:",np.mean(trainloss2))
print("train_errorloss:",np.mean(testloss2))
plt.plot(trainloss2)
plt.plot(testloss2)
plt.legend(('train','test'))
plt.show()
# Out:
# train_errorloss: 0.977253374462
# train_errorloss: 0.976899352165

# %%
clf3 = SGDClassifier(loss='log', penalty='l2', learning_rate='constant',class_weight={0:0.64,1:2.3}, n_jobs=-1, random_state=10, eta0=0.01)

# %%
trainloss3 = []
testloss3 = []

for i,chunk in enumerate(pd.read_csv('data_train.csv', chunksize=chunksize)):
    X_train = fh.transform(np.asarray(chunk.iloc[:,0:-1].astype(str)))
    y_train = chunk.iloc[:,-1]    
    clf3.partial_fit(X_train,y_train,classes=[0,1])
    fpr, tpr, thresholds = metrics.roc_curve(y_train,clf3.predict(X_train))
    trainloss3.append(metrics.auc(fpr, tpr))
    fpr_t, tpr_t, thresholds_t = metrics.roc_curve(y_test,clf3.predict(X_test))
    testloss3.append(metrics.auc(fpr_t, tpr_t))

# %%
print("train_errorloss:",np.mean(trainloss3))
print("train_errorloss:",np.mean(testloss3))
plt.plot(trainloss3)
plt.plot(testloss3)
plt.legend(('train','test'))
plt.show()
# Out:
# train_errorloss: 0.978625997178
# train_errorloss: 0.977292906813

# %%
clf4 = SGDClassifier(loss='log', penalty='l2', learning_rate='constant',class_weight={0:0.64,1:2.3}, n_jobs=-1, random_state=10, eta0=0.01)

# %%
trainloss4 = []
testloss4 = []

for i,chunk in enumerate(pd.read_csv('data_train.csv', chunksize=chunksize)):
    X_train = fh.transform(np.asarray(chunk.iloc[:,0:-1].astype(str)))
    y_train = chunk.iloc[:,-1]    
    clf4.partial_fit(X_train,y_train,classes=[0,1])
    fpr, tpr, thresholds = metrics.roc_curve(y_train,clf4.predict(X_train))
    trainloss4.append(metrics.auc(fpr, tpr))
    fpr_t, tpr_t, thresholds_t = metrics.roc_curve(y_test,clf4.predict(X_test))
    testloss4.append(metrics.auc(fpr_t, tpr_t))

# %%
print("train_errorloss:",np.mean(trainloss4))
print("train_errorloss:",np.mean(testloss4))
plt.plot(trainloss4)
plt.plot(testloss4)
plt.legend(('train','test'))
plt.show()
# Out:
# train_errorloss: 0.978625997178
# train_errorloss: 0.977292906813

# %%
from sklearn.naive_bayes import BernoulliNB
clf5 = BernoulliNB()

# %%
trainloss5 = []
testloss5 = []

for i,chunk in enumerate(pd.read_csv('data_train.csv', chunksize=chunksize)):
    X_train = fh.transform(np.asarray(chunk.iloc[:,0:-1].astype(str)))
    y_train = chunk.iloc[:,-1]    
    clf5.partial_fit(X_train,y_train,classes=[0,1])
    fpr, tpr, thresholds = metrics.roc_curve(y_train,clf4.predict(X_train))
    trainloss5.append(metrics.auc(fpr, tpr))
    fpr_t, tpr_t, thresholds_t = metrics.roc_curve(y_test,clf4.predict(X_test))
    testloss5.append(metrics.auc(fpr_t, tpr_t))

# %%
print("train_errorloss:",np.mean(trainloss5))
print("train_errorloss:",np.mean(testloss5))
plt.plot(trainloss5)
plt.plot(testloss5)
plt.legend(('train','test'))
plt.show()
# Out:
# train_errorloss: 0.976606657603
# train_errorloss: 0.976451805781
